# %% [markdown]
# Tasks achieved in this version:
# 1. Separate the function of returning json and map
# 2. Connect with database storing map html file
# 3. Format input
# * Token is updated

# %%
import psycopg2
import pandas.io.sql as sqlio
import folium
import pandas as pd
import numpy as np
import json
from itertools import combinations,permutations
import requests
from datetime import datetime
from python_tsp.exact import solve_tsp_dynamic_programming
import geojson
from geojson import Feature,FeatureCollection,MultiLineString
from flask import Flask,request,render_template

def db_init(poi_list):
    engine = psycopg2.connect(
    database="demo_1",
    user="postgres",
    password="Huxjoffer2021!",
    host="database-1-test.ctpfk8jpyqbl.us-east-1.rds.amazonaws.com",
    port='5432')
    postgreSQL_select_Query=''
    for i in range(len(poi_list)):
        if i==0:
            postgreSQL_select_Query+="select * from poi where poi_name='"+poi_list[i]+"'"
        else:
            postgreSQL_select_Query+="union all select * from poi where poi_name='"+poi_list[i]+"'"
    df= sqlio.read_sql_query(postgreSQL_select_Query, engine)
    df.drop(columns=['id'],inplace=True)
    return df

def map_db_init():
    engine = psycopg2.connect(
    database="database_map",
    user="postgres",
    password="Huxjoffer2021!",
    host="database-map.ctpfk8jpyqbl.us-east-1.rds.amazonaws.com",
    port='5432')
    return engine

# for each place combination, query onemap
def construct_matrix(combination_list,mydf):
    distance_matrix=np.zeros((len(mydf),len(mydf)))
    iti_matrix=np.empty((len(mydf),len(mydf)),dtype='object')

    for i in combination_list:  
        start=str(mydf.loc[(mydf['poi_name']==i[0]),['latitude']].values[0][0])+','+str(mydf.loc[(mydf['poi_name']==i[0]),['longitude']].values[0][0])
        end=str(mydf.loc[(mydf['poi_name']==i[1]),['latitude']].values[0][0])+','+str(mydf.loc[(mydf['poi_name']==i[1]),['longitude']].values[0][0])

        duration_list=[]
        min_dur=1000000
        response_list=[]
        num_iti=[]
        selected_iti=None

        om_token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..aIKS_YiyD6BG-YMigniabKU7PyYoBKfab_TN1FsqD-0'
        routeType='pt'
        mode=['TRANSIT','BUS']
        head='https://developers.onemap.sg/privateapi/routingsvc/route?'
        dt=datetime.now().strftime("%Y-%m-%d")
        tm=datetime.now().strftime('%H:%M:%S')

        for j in mode: # each mode
            url=head+'start='+start+'&end='+end+'&routeType='+routeType+'&token='+om_token+'&date='+str(dt)+'&time='+str(tm)+'&mode='+j+'&numItineraries='+str(3)
            temp_rp=requests.get(url=url)
            # how to handle bad request? (500, 504 etc.) One way is to slightly change the coordinates of the location
            temp_response_json=temp_rp.json()
            response_list.append(temp_response_json)

            temp_num_iti=len(temp_response_json['plan']['itineraries']) # ranges from 1 to 3
            num_iti.append(temp_num_iti)
            for k in range(temp_num_iti): # each possible itinerary
                temp_dur=temp_response_json['plan']['itineraries'][k]['duration']
                duration_list.append(temp_dur)
                min_dur=min(min_dur,temp_dur)
        best_dur_index=duration_list.index(min_dur) # ranges from 0 to 5
        if best_dur_index<=num_iti[0]-1: # belongs to transit
            selected_iti=response_list[0]['plan']['itineraries'][best_dur_index]
        else: # belongs to bus
            selected_iti=response_list[1]['plan']['itineraries'][best_dur_index-num_iti[0]]

        # min_dur write into matrix
        x=mydf.loc[(mydf['poi_name']==i[0])].index.values[0]
        y=mydf.loc[(mydf['poi_name']==i[1])].index.values[0]
        distance_matrix[x][y]=min_dur
        distance_matrix[y][x]=min_dur
        iti_matrix[x][y]=selected_iti
        iti_matrix[y][x]=selected_iti
    return distance_matrix,iti_matrix

# find shortest path
def shortest_path(distance_matrix):
    distance_matrix[:, 0] = 0
    permutation, distance = solve_tsp_dynamic_programming(distance_matrix)
    return permutation,distance

def visualisation(permutation,iti_matrix,mydf):
    #j={}
    j_list=[]
    # draw folium graph
    str_fea_list=[]
    tooltip = 'Click For More Info'
    des_dict={'WALK':'Walk to ','SUBWAY':'Take subway to ','BUS':'Take bus to '}
    m = folium.Map(location=[1.2791,103.8154], zoom_start=12)
    for i in range(len(permutation)-1): # for one itinerary
        sta_plc_idx=permutation[i]
        end_plc_idx=permutation[i+1]
        itinerary=iti_matrix[sta_plc_idx][end_plc_idx]

        true_sta_pt=np.array((mydf._get_value(sta_plc_idx,'latitude'),mydf._get_value(sta_plc_idx,'longitude')))
        true_end_pt=np.array((mydf._get_value(end_plc_idx,'latitude'),mydf._get_value(end_plc_idx,'longitude')))

        temp_num_legs=len(itinerary['legs']) # num of legs
        pt_lat=[]
        pt_lon=[]
        tpl_list=[]
        pt_name=[]
        mode_list=[]
        dist_list=[]
        for k in range(temp_num_legs): # for each leg
            pt_lon.append(itinerary['legs'][k]['from']['lon'])
            pt_lat.append(itinerary['legs'][k]['from']['lat'])
            tpl_list.append((itinerary['legs'][k]['from']['lon'],itinerary['legs'][k]['from']['lat']))
            pt_name.append(itinerary['legs'][k]['to']['name'])
            mode_list.append(des_dict[itinerary['legs'][k]['mode']])
            dist_list.append(str(round(float(itinerary['legs'][k]['distance'])/1000,2))+' km.')
            if k==temp_num_legs-1:
                pt_lon.append(itinerary['legs'][k]['to']['lon'])
                pt_lat.append(itinerary['legs'][k]['to']['lat'])
                tpl_list.append((itinerary['legs'][k]['to']['lon'],itinerary['legs'][k]['to']['lat']))
        temp_feature=Feature(geometry=MultiLineString([tpl_list]),properties={'stroke':'#AF4646'})
        str_fea_list.append(temp_feature)
        first_point=np.array((pt_lat[0],pt_lon[0]))

        distance1 = np.linalg.norm(first_point-true_sta_pt)
        distance2 = np.linalg.norm(first_point-true_end_pt)

        start_point=[pt_lat[0],pt_lon[0]]
        end_point=[pt_lat[-1],pt_lon[-1]]
        iterator=range(len(mode_list))
        # only affect formatting the text
        string=''
        if distance1>distance2:
            iterator=range(len(mode_list)-1,-1,-1)
            start_point=[pt_lat[-1],pt_lon[-1]]
            end_point=[pt_lat[0],pt_lon[0]]
        counter=0
        for j in iterator:
            string+=str(counter+1)+'. '+mode_list[j]+pt_name[j]+'. Estimated distance is '+dist_list[j]+'\n'
            counter+=1

        folium.Marker(start_point,
                  popup='<strong>'+string+'</strong>',
                  tooltip=tooltip,
                  icon=folium.Icon(icon='trophy' if i!=0 else 'flag')).add_to(m),
        folium.Marker(end_point,icon=folium.Icon(icon='trophy' if i!=len(permutation)-2 else 'star')).add_to(m)

        temp_j_ele={}
        temp_j_ele['order']=i+1
        temp_j_ele['poi_name']=mydf._get_value(end_plc_idx,'poi_name')
        temp_j_ele['time_to_spend']=mydf._get_value(end_plc_idx,'time')
        j_list.append(temp_j_ele)
    
    print(j_list)
    j={'itinerary':j_list}
    j_file=json.dumps(j)
        
    feature_collection=FeatureCollection(str_fea_list)
    ms=geojson.dumps(feature_collection)
    folium.GeoJson(ms, name='multistring').add_to(m)

    # Generate map
    render_m=m.get_root().render()
    # insert value into map_database
    
    map_engine=map_db_init()
    insert_req = "INSERT INTO map_db (id,map_html) VALUES (default,"+"'"+render_m+"')"
    print(insert_req)
    cursor = map_engine.cursor()
    cursor.execute(insert_req)
    map_engine.commit()
    
    return j_file

# %%
poi_list=['COM1, NUS','Hort Park','Chinatown','National Museum']

# %%
mydf=db_init(poi_list)

# this function: input: list of coordinate of each POI, return matrix
comb = combinations(mydf['poi_name'], 2)  
comb_list=list(comb)
distance_matrix,iti_matrix=construct_matrix(comb_list,mydf)
permutation,distance=shortest_path(distance_matrix)
j_file=visualisation(permutation,iti_matrix,mydf)
print(j_file)
print(type(j_file))
# Out:
# [{'order': 1, 'poi_name': 'Hort Park', 'time_to_spend': 1.0}, {'order': 2, 'poi_name': 'Chinatown', 'time_to_spend': 2.0}, {'order': 3, 'poi_name': 'National Museum', 'time_to_spend': 1.5}]
# INSERT INTO map_db (id,map_html) VALUES (default,'<!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_080a7ddd6f2c4833b99f791f59e4e494 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_080a7ddd6f2c4833b99f791f59e4e494" ></div>
#
# </body>
# <script>
#
#             var map_080a7ddd6f2c4833b99f791f59e4e494 = L.map(
#                 "map_080a7ddd6f2c4833b99f791f59e4e494",
#                 {
#                     center: [1.2791, 103.8154],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d5fcbbccc2a4656b086e00657c4d12f = L.tileLayer(
#                 "https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
#                 {"attribution": "Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://www.openstreetmap.org/copyright\"\u003eODbL\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var marker_d9fee8dd062e4256a388d7268d62359a = L.marker(
#                 [1.2949064295359, 103.77367779636],
#                 {}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var icon_b8b43bd2dd974a18816efb1365431d0d = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "flag", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_d9fee8dd062e4256a388d7268d62359a.setIcon(icon_b8b43bd2dd974a18816efb1365431d0d);
#
#
#         var popup_a8a95869dd9d4a17b54ef5c88d3f8a63 = L.popup({"maxWidth": "100%"});
#
#
#             var html_eb57f2d0ba5140cb89dff62a50aa1170 = $(`<div id="html_eb57f2d0ba5140cb89dff62a50aa1170" style="width: 100.0%; height: 100.0%;"><strong>1. Walk to KENT RIDGE TER. Estimated distance is 0.73 km. 2. Take bus to HARBOURSIDE IND BLDG 2. Estimated distance is 4.03 km. 3. Walk to Destination. Estimated distance is 0.99 km. </strong></div>`)[0];
#             popup_a8a95869dd9d4a17b54ef5c88d3f8a63.setContent(html_eb57f2d0ba5140cb89dff62a50aa1170);
#
#
#         marker_d9fee8dd062e4256a388d7268d62359a.bindPopup(popup_a8a95869dd9d4a17b54ef5c88d3f8a63)
#         ;
#
#
#
#
#             marker_d9fee8dd062e4256a388d7268d62359a.bindTooltip(
#                 `<div>
#                      Click For More Info
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_49202f9f6a8f4c5ab854fe69787f06d1 = L.marker(
#                 [1.2791094023419, 103.79944472002],
#                 {}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var icon_bb6f3e2dbbe047e7af1c76746de4e4fe = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "trophy", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_49202f9f6a8f4c5ab854fe69787f06d1.setIcon(icon_bb6f3e2dbbe047e7af1c76746de4e4fe);
#
#
#             var marker_211375a02c934c11833b39cbdd27725c = L.marker(
#                 [1.2791094023419, 103.79944472002],
#                 {}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var icon_b6d5745799dc4d87b1f0dadaeee74e21 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "trophy", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_211375a02c934c11833b39cbdd27725c.setIcon(icon_b6d5745799dc4d87b1f0dadaeee74e21);
#
#
#         var popup_1c8176a68dea490fbd3c1caf2520dcaf = L.popup({"maxWidth": "100%"});
#
#
#             var html_6b7413f32f12408ebe5c6f970d97debf = $(`<div id="html_6b7413f32f12408ebe5c6f970d97debf" style="width: 100.0%; height: 100.0%;"><strong>1. Walk to HARBOURSIDE IND BLDG 2. Estimated distance is 0.99 km. 2. Take bus to OPP VIVOCITY. Estimated distance is 3.04 km. 3. Walk to HARBOURFRONT MRT STATION. Estimated distance is 0.1 km. 4. Take subway to CHINATOWN MRT STATION. Estimated distance is 3.2 km. 5. Walk to NEW BRIDGE CTR. Estimated distance is 0.15 km. 6. Walk to Destination. Estimated distance is 0.33 km. </strong></div>`)[0];
#             popup_1c8176a68dea490fbd3c1caf2520dcaf.setContent(html_6b7413f32f12408ebe5c6f970d97debf);
#
#
#         marker_211375a02c934c11833b39cbdd27725c.bindPopup(popup_1c8176a68dea490fbd3c1caf2520dcaf)
#         ;
#
#
#
#
#             marker_211375a02c934c11833b39cbdd27725c.bindTooltip(
#                 `<div>
#                      Click For More Info
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_98dc7998ea824ec99c66ed87a82f8a22 = L.marker(
#                 [1.2814272873608, 103.84423200277],
#                 {}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var icon_72d9b52116854ddda06dbba472febb9f = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "trophy", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_98dc7998ea824ec99c66ed87a82f8a22.setIcon(icon_72d9b52116854ddda06dbba472febb9f);
#
#
#             var marker_b9d4dbe4b556485e8462023595915be5 = L.marker(
#                 [1.2814272873608, 103.84423200277],
#                 {}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var icon_0d854527286142f4bf876069665d497f = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "trophy", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_b9d4dbe4b556485e8462023595915be5.setIcon(icon_0d854527286142f4bf876069665d497f);
#
#
#         var popup_26e081ceda1b4673b87d4bebffa57c91 = L.popup({"maxWidth": "100%"});
#
#
#             var html_261775502779485ebfb269d39eb01910 = $(`<div id="html_261775502779485ebfb269d39eb01910" style="width: 100.0%; height: 100.0%;"><strong>1. Walk to path. Estimated distance is 0.33 km. 2. Walk to CHINATOWN MRT STATION. Estimated distance is 0.15 km. 3. Take subway to DHOBY GHAUT MRT STATION. Estimated distance is 1.86 km. 4. Walk to DHOBY GHAUT MRT STATION. Estimated distance is 0.17 km. 5. Walk to Destination. Estimated distance is 0.43 km. </strong></div>`)[0];
#             popup_26e081ceda1b4673b87d4bebffa57c91.setContent(html_261775502779485ebfb269d39eb01910);
#
#
#         marker_b9d4dbe4b556485e8462023595915be5.bindPopup(popup_26e081ceda1b4673b87d4bebffa57c91)
#         ;
#
#
#
#
#             marker_b9d4dbe4b556485e8462023595915be5.bindTooltip(
#                 `<div>
#                      Click For More Info
#                  </div>`,
#                 {"sticky": true}
#             );
#
#
#             var marker_7639edf5d15443ec82052953638a0799 = L.marker(
#                 [1.2966263915816, 103.848509901],
#                 {}
#             ).addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#
#
#             var icon_2d12690cbf9747dba02857510f4ceaf2 = L.AwesomeMarkers.icon(
#                 {"extraClasses": "fa-rotate-0", "icon": "star", "iconColor": "white", "markerColor": "blue", "prefix": "glyphicon"}
#             );
#             marker_7639edf5d15443ec82052953638a0799.setIcon(icon_2d12690cbf9747dba02857510f4ceaf2);
#
#
#
#         function geo_json_7f5230697c5543d9a06de58521ef2a1a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7f5230697c5543d9a06de58521ef2a1a = L.geoJson(null, {
#                 onEachFeature: geo_json_7f5230697c5543d9a06de58521ef2a1a_onEachFeature,
#
#         });
#
#         function geo_json_7f5230697c5543d9a06de58521ef2a1a_add (data) {
#             geo_json_7f5230697c5543d9a06de58521ef2a1a
#                 .addData(data)
#                 .addTo(map_080a7ddd6f2c4833b99f791f59e4e494);
#         }
#             geo_json_7f5230697c5543d9a06de58521ef2a1a_add({"features": [{"geometry": {"coordinates": [[[103.773678, 1.294906], [103.769883, 1.294253], [103.79674, 1.274815], [103.799445, 1.279109]]], "type": "MultiLineString"}, "properties": {"stroke": "#AF4646"}, "type": "Feature"}, {"geometry": {"coordinates": [[[103.799445, 1.279109], [103.79674, 1.274815], [103.822283, 1.265924], [103.82153, 1.265389], [103.84325, 1.284095], [103.842543, 1.282938], [103.844232, 1.281427]]], "type": "MultiLineString"}, "properties": {"stroke": "#AF4646"}, "type": "Feature"}, {"geometry": {"coordinates": [[[103.844232, 1.281427], [103.842543, 1.282938], [103.84325, 1.284095], [103.845376, 1.299621], [103.84673, 1.298805], [103.84851, 1.296626]]], "type": "MultiLineString"}, "properties": {"stroke": "#AF4646"}, "type": "Feature"}], "type": "FeatureCollection"});
#
#
# </script>')
# {"itinerary": [{"order": 1, "poi_name": "Hort Park", "time_to_spend": 1.0}, {"order": 2, "poi_name": "Chinatown", "time_to_spend": 2.0}, {"order": 3, "poi_name": "National Museum", "time_to_spend": 1.5}]}
# <class 'str'>

# %%
map_engine=map_db_init()
postgreSQL_select_Query = "select map_html from map_db order by id desc limit 1"
cursor = map_engine.cursor()
cursor.execute(postgreSQL_select_Query)
html = cursor.fetchall()
return html[0][0]
# Out:
# abc
# <class 'str'>

# %%
# initialise app
app=Flask(__name__)

@app.route("/optimisation",methods=['GET','POST'])
def optimisation():
    mydf=db_init()

    # this function: input: list of coordinate of each POI, return matrix
    comb = combinations(mydf['poi_name'], 2)  
    comb_list=list(comb)
    distance_matrix,iti_matrix=construct_matrix(comb_list,mydf)
    permutation,distance=shortest_path(distance_matrix)
    m=visualisation(permutation,iti_matrix,mydf)
    return '<h1>success</h1>'

@app.route("/map",methods=['GET','POST'])
def map():
    return m

@app.route("/")
def home():
    return "<h1>Hello World</h1>"

# entrance
if __name__=='__main__':
    #app.run(host='0.0.0.0',port=8080)
    app.run(debug=True)
    #host='0.0.0.0',port=8080
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\I544708\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
